# %% [markdown]
# Imports and Data Loading
#
# We will bring in our standard libraries, plus the regularization models, the scaler for standardizing features, and GridSearchCV for hyperparameter tuning.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_diabetes
from sklearn.linear_model import ElasticNet, Lasso, LinearRegression, Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler

# Load the dataset
diabetes = load_diabetes(as_frame=True)
df = diabetes.frame
X = df.drop(columns=["target"])
y = df["target"]

print("Data loaded successfully.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.subplots as plt
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 import pandas as pd
#
# ModuleNotFoundError: No module named 'matplotlib.subplots'

# %% [markdown]
# EDA, Splitting, and Standardizing
#
# Regularized regression models are highly sensitive to the scale of the input features. Therefore, standardizing the features (mean = 0, variance = 1) is a critical professional practice before applying Ridge or Lasso.

# %% [markdown]
# Training and Tuning Models with GridSearchCV
#
# We will set up a dictionary to store our models and use GridSearchCV to test a range of alpha values (the penalty term) to find the absolute best version of each model.

# %% [markdown]
# Model Comparison and Evaluation
#
# We will loop through our fitted models, make predictions, and calculate our metrics (MAE, RMSE, and $R^2$) to compare their performance side-by-side

# %% [markdown]
# Identifying Influential Predictors
#
# To find the most influential predictors, we look at the absolute values of the coefficients from our best-performing model (which is usually Ridge or Lasso in this scenario).

# %% [markdown]
# ### Final Recommendation and Justification
#
# Based on the evaluation metrics, **[Insert Winning Model Name, e.g., Ridge Regression]** is the recommended model.
#
# **Justification:**
# 1. **Highest R² Score:** It achieved the highest $R^2$ of **[Insert R² score]**, meaning it explains the greatest variance in disease progression compared to the others.
# 2. **Lowest Error Rates:** It minimized the prediction errors, yielding the lowest Root Mean Squared Error (RMSE) and Mean Absolute Error (MAE).
# 3. **Reduced Overfitting:** By applying an L2 penalty (alpha = **[Insert Alpha]**), it successfully stabilized the coefficients, handling potential multicollinearity better than standard Linear Regression without entirely dropping features like Lasso might.
